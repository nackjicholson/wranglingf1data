# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql://root:root@localhost:3306/f1db')

connection = engine.connect()

# %%
data = {}

for table_name in engine.table_names():
    query = 'select * from %s' % table_name
    data[table_name] = pd.read_sql(query, con=connection)

# %%
# data['constructors'][[x for x in range(0, 3)]].merge(data['constructorResults'], on='constructorId').head(5)
data['constructors'].iloc[:, 0:3].merge(data['constructorResults'], on='constructorId').head(5)
# Out:
#    constructorId constructorRef     name  constructorResultsId  raceId  \
# 0              1        mclaren  McLaren                     1      18
# 1              1        mclaren  McLaren                    14      19
# 2              1        mclaren  McLaren                    25      20
# 3              1        mclaren  McLaren                    35      21
# 4              1        mclaren  McLaren                    46      22
#
#    points status
# 0    14.0   None
# 1    10.0   None
# 2     4.0   None
# 3     6.0   None
# 4     8.0   None

# %%
data['constructorStandings'].head(5)
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins
# 0            1     1
# 1            3     0
# 2            2     0
# 3            4     0
# 4            5     0

# %%
data['driverStandings'].head(5)
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
data['drivers'].head(5)
# Out:
#    driverId   driverRef  number code  forename     surname         dob  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg     6.0  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso    14.0  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
data['lapTimes'].head(5)
# Out:
#    raceId  driverId  lap  position      time  milliseconds
# 0     841        20    1         1  1:38.109         98109
# 1     841        20    2         1  1:33.006         93006
# 2     841        20    3         1  1:32.713         92713
# 3     841        20    4         1  1:32.803         92803
# 4     841        20    5         1  1:32.342         92342

# %%
data['pitStops'].head(5)
# Out:
#    raceId  driverId  stop  lap     time duration  milliseconds
# 0     841       153     1    1 17:05:23   26.898         26898
# 1     841        30     1    1 17:05:52   25.021         25021
# 2     841        17     1   11 17:20:48   23.426         23426
# 3     841         4     1   12 17:22:34   23.251         23251
# 4     841        13     1   13 17:24:10   23.842         23842

# %%
data['qualifying'].head(5)
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
data['races'].head(5)
# Out:
#    raceId  year  round  circuitId                   name        date     time  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29 06:00:00
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05 09:00:00
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19 07:00:00
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26 12:00:00
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10 12:00:00
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
data['results'].head(5)
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps         time  milliseconds  \
# 0            1              1    10.0    58  1:34:50.616     5690616.0
# 1            2              2     8.0    58       +5.478     5696094.0
# 2            3              3     6.0    58       +8.163     5698779.0
# 3            4              4     5.0    58      +17.181     5707797.0
# 4            5              5     4.0    58      +18.014     5708630.0
#
#    fastestLap  rank fastestLapTime fastestLapSpeed  statusId
# 0        39.0   2.0       1:27.452         218.300         1
# ...

# %%
data['status'].head(5)
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
connection.close()
